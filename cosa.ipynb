# %%
import pandas as pd

# URL que apunta al contenido raw de GitHub
url = "https://raw.githubusercontent.com/aiambo08/anime-recommendation/main/rating.csv"

try:
    df = pd.read_csv(url)
    print(df.head())
except Exception as e:
    print(f"Error al leer el archivo: {e}")
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:f2cf790539cff9c7ac462d546381493a574...
# 1                                     size 111404899
